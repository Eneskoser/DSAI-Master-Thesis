# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../data/hourly_transportation_202105.csv")

# %%
df.head()
# Out:
#   transition_date  transition_hour  transport_type_id road_type  \
# 0      2021-05-01                0                  1    OTOYOL
# 1      2021-05-01                0                  1    OTOYOL
# 2      2021-05-01                0                  1    OTOYOL
# 3      2021-05-01                0                  1    OTOYOL
# 4      2021-05-01                0                  1    OTOYOL
#
#                    line transfer_type  number_of_passage  number_of_passenger  \
# 0  AVCILAR-ZINCIRLIKUYU        Normal                  1                    1
# 1  AVCILAR-ZINCIRLIKUYU        Normal                  2                    1
# 2  SULTANBEYLI-UMRANIYE        Normal                  3                    3
# 3  AVCILAR-ZINCIRLIKUYU        Normal                  2                    2
# 4  AVCILAR-ZINCIRLIKUYU        Normal                  1                    1
#
#   product_kind transaction_type_desc          town line_name  \
# 0   INDIRIMLI1      Indirimli Kontur    BAYRAMPASA        34
# 1     UCRETSIZ              Ucretsiz  KUCUKCEKMECE        34
# 2          TAM            Tam Kontur      BAKIRKOY       131
# 3     UCRETSIZ              Ucretsiz   ZEYTINBURNU        34
# 4   INDIRIMLI1      Indirimli Kontur       BEYOGLU        34
#
#   station_poi_desc_cd
# 0        EDIRNEKAPI 2
# 1             SEFAKOY
# 2                 NaN
# 3          CEVIZLIBAG
# 4          HALICIOGLU

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7238254 entries, 0 to 7238253
# Data columns (total 13 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   transition_date        object
#  1   transition_hour        int64
#  2   transport_type_id      int64
#  3   road_type              object
#  4   line                   object
#  5   transfer_type          object
#  6   number_of_passage      int64
#  7   number_of_passenger    int64
#  8   product_kind           object
#  9   transaction_type_desc  object
#  10  town                   object
#  11  line_name              object
#  12  station_poi_desc_cd    object
# dtypes: int64(4), object(9)
# memory usage: 717.9+ MB

# %%
df.describe()
# Out:
#        transition_hour  transport_type_id  number_of_passage  \
# count     7.238254e+06       7.238254e+06       7.238254e+06
# mean      1.332651e+01       1.319976e+00       9.266028e+00
# std       4.788097e+00       5.310547e-01       3.084617e+01
# min       0.000000e+00       1.000000e+00       1.000000e+00
# 25%       9.000000e+00       1.000000e+00       1.000000e+00
# 50%       1.400000e+01       1.000000e+00       2.000000e+00
# 75%       1.700000e+01       2.000000e+00       6.000000e+00
# max       2.300000e+01       3.000000e+00       2.062000e+03
#
#        number_of_passenger
# count         7.238254e+06
# mean          9.243876e+00
# std           3.082515e+01
# min           1.000000e+00
# 25%           1.000000e+00
# 50%           2.000000e+00
# 75%           6.000000e+00
# max           2.061000e+03

# %%
df[["transport_type_id","road_type"]].drop_duplicates()
# Out:
#      transport_type_id road_type
# 0                    1    OTOYOL
# 8                    3     DENİZ
# 797                  2     RAYLI

# %%
df.head(100).to_csv("../data/sample_data.csv")
